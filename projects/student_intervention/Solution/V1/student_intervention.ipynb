# %% [markdown]
# # Machine Learning Engineer Nanodegree
# ## Supervised Learning
# ## Project: Building a Student Intervention System

# %% [markdown]
# Welcome to the second project of the Machine Learning Engineer Nanodegree! In this notebook, some template code has already been provided for you, and it will be your job to implement the additional functionality necessary to successfully complete this project. Sections that begin with **'Implementation'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `'TODO'` statement. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ### Question 1 - Classification vs. Regression
# *Your goal for this project is to identify students who might need early intervention before they fail to graduate. Which type of supervised learning problem is this, classification or regression? Why?*

# %% [markdown]
# **Answer: ** This is typically a classification problem as we are only targetting to classify students under one of the following two categories:
#
# Category 1: [Clever Student] Student doesn't need intervention as he will probably successully pass without intervention
#
# Category 2: [Lazy Student] Student require intervention as probably he will fail to pass if no intervention too place

# %% [markdown]
# ## Exploring the Data
# Run the code cell below to load necessary Python libraries and load the student data. Note that the last column from this dataset, `'passed'`, will be our target label (whether the student graduated or didn't graduate). All other columns are features about each student.

# %%
# Import libraries
import numpy as np
import pandas as pd
from time import time
from sklearn.metrics import f1_score

# Read student data
student_data = pd.read_csv("student-data.csv")
print "Student data read successfully!"
# Out:
# Student data read successfully!

# %% [markdown]
# ### Implementation: Data Exploration
# Let's begin by investigating the dataset to determine how many students we have information on, and learn about the graduation rate among these students. In the code cell below, you will need to compute the following:
# - The total number of students, `n_students`.
# - The total number of features for each student, `n_features`.
# - The number of those students who passed, `n_passed`.
# - The number of those students who failed, `n_failed`.
# - The graduation rate of the class, `grad_rate`, in percent (%).

# %%
# TODO: Calculate number of students
n_students = len(student_data)

# TODO: Calculate number of features
n_features = len(student_data.columns)

# TODO: Calculate passing students
n_passed = len(student_data[student_data.passed == 'yes'])

# TODO: Calculate failing students
n_failed = len(student_data[student_data.passed == 'no'])

# TODO: Calculate graduation rate
grad_rate = n_passed * 100. / (n_passed + n_failed)

# Print the results
print "Total number of students: {}".format(n_students)
print "Number of features: {}".format(n_features)
print "Number of students who passed: {}".format(n_passed)
print "Number of students who failed: {}".format(n_failed)
print "Graduation rate of the class: {:.2f}%".format(grad_rate)
# Out:
# Total number of students: 395
# Number of features: 31
# Number of students who passed: 265
# Number of students who failed: 130
# Graduation rate of the class: 67.09%

# %% [markdown]
# ## Preparing the Data
# In this section, we will prepare the data for modeling, training and testing.
#
# ### Identify feature and target columns
# It is often the case that the data you obtain contains non-numeric features. This can be a problem, as most machine learning algorithms expect numeric data to perform computations with.
#
# Run the code cell below to separate the student data into feature and target columns to see if any features are non-numeric.

# %%
# Extract feature columns
feature_cols = list(student_data.columns[:-1])

# Extract target column 'passed'
target_col = student_data.columns[-1] 

# Show the list of columns
print "Feature columns:\n{}".format(feature_cols)
print "\nTarget column: {}".format(target_col)

# Separate the data into feature data and target data (X_all and y_all, respectively)
X_all = student_data[feature_cols]
y_all = student_data[target_col]

# Show the feature information by printing the first five rows
print "\nFeature values:"
print X_all.head()
# Out:
# Feature columns:
# ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences']
#
# Target column: passed
#
# Feature values:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#     ...    higher internet  romantic  famrel  freetime goout Dalc Walc health  \
# 0   ...       yes       no        no       4         3     4    1    1      3
# 1   ...       yes      yes        no       5         3     3    1    1      3
# 2   ...       yes      yes        no       4         3     2    2    3      3
# 3   ...       yes      yes       yes       3         2     2    1    1      5
# 4   ...       yes       no        no       4         3     2    1    2      5
#
#   absences
# 0        6
# 1        4
# 2       10
# 3        2
# 4        4
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Preprocess Feature Columns
#
# As you can see, there are several non-numeric columns that need to be converted! Many of them are simply `yes`/`no`, e.g. `internet`. These can be reasonably converted into `1`/`0` (binary) values.
#
# Other columns, like `Mjob` and `Fjob`, have more than two values, and are known as _categorical variables_. The recommended way to handle such a column is to create as many columns as possible values (e.g. `Fjob_teacher`, `Fjob_other`, `Fjob_services`, etc.), and assign a `1` to one of them and `0` to all others.
#
# These generated columns are sometimes called _dummy variables_, and we will use the [`pandas.get_dummies()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html?highlight=get_dummies#pandas.get_dummies) function to perform this transformation. Run the code cell below to perform the preprocessing routine discussed in this section.

# %%
def preprocess_features(X):
    ''' Preprocesses the student data and converts non-numeric binary variables into
        binary (0/1) variables. Converts categorical variables into dummy variables. '''
    
    # Initialize new output DataFrame
    output = pd.DataFrame(index = X.index)

    # Investigate each feature column for the data
    for col, col_data in X.iteritems():
        
        # If data type is non-numeric, replace all yes/no values with 1/0
        if col_data.dtype == object:
            col_data = col_data.replace(['yes', 'no'], [1, 0])
            print "=> col_data type: {}  {}".format(col, col_data)
            
        if col_data.dtype == object:
            # Example: 'school' => 'school_GP' and 'school_MS'
            col_data = pd.get_dummies(col_data, prefix = col)  
            print "==> col_data type: {}  {}".format(col, col_data)
        
        # Collect the revised columns
        output = output.join(col_data)
    
    return output

X_all = preprocess_features(X_all)
print "Processed feature columns ({} total features):\n{}".format(len(X_all.columns), list(X_all.columns))

# print X_all.head()
# Out:
# Processed feature columns (48 total features):
# ['school_GP', 'school_MS', 'sex_F', 'sex_M', 'age', 'address_R', 'address_U', 'famsize_GT3', 'famsize_LE3', 'Pstatus_A', 'Pstatus_T', 'Medu', 'Fedu', 'Mjob_at_home', 'Mjob_health', 'Mjob_other', 'Mjob_services', 'Mjob_teacher', 'Fjob_at_home', 'Fjob_health', 'Fjob_other', 'Fjob_services', 'Fjob_teacher', 'reason_course', 'reason_home', 'reason_other', 'reason_reputation', 'guardian_father', 'guardian_mother', 'guardian_other', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences']

# %% [markdown]
# ### Implementation: Training and Testing Data Split
# So far, we have converted all _categorical_ features into numeric values. For the next step, we split the data (both features and corresponding labels) into training and test sets. In the following code cell below, you will need to implement the following:
# - Randomly shuffle and split the data (`X_all`, `y_all`) into training and testing subsets.
#   - Use 300 training points (approximately 75%) and 95 testing points (approximately 25%).
#   - Set a `random_state` for the function(s) you use, if provided.
#   - Store the results in `X_train`, `X_test`, `y_train`, and `y_test`.

# %%
# TODO: Import any additional functionality you may need here
from sklearn import cross_validation

# TODO: Set the number of training points
num_train = 300

# Set the number of testing points
num_test = X_all.shape[0] - num_train

# TODO: Shuffle and split the dataset into the number of training and testing points above
# X_train = None
# X_test = None
# y_train = None
# y_test = None

X_train, X_test, y_train, y_test = cross_validation.train_test_split(X_all, y_all, test_size=num_test, random_state=30)


# Show the results of the split
print "Training set has {} samples.".format(X_train.shape[0])
print "Testing set has {} samples.".format(X_test.shape[0])
# Out:
# Training set has 300 samples.
# Testing set has 95 samples.

# %% [markdown]
# ## Training and Evaluating Models
# In this section, you will choose 3 supervised learning models that are appropriate for this problem and available in `scikit-learn`. You will first discuss the reasoning behind choosing these three models by considering what you know about the data and each model's strengths and weaknesses. You will then fit the model to varying sizes of training data (100 data points, 200 data points, and 300 data points) and measure the F<sub>1</sub> score. You will need to produce three tables (one for each model) that shows the training set size, training time, prediction time, F<sub>1</sub> score on the training set, and F<sub>1</sub> score on the testing set.
#
# **The following supervised learning models are currently available in** [`scikit-learn`](http://scikit-learn.org/stable/supervised_learning.html) **that you may choose from:**
# - Gaussian Naive Bayes (GaussianNB)
# - Decision Trees
# - Ensemble Methods (Bagging, AdaBoost, Random Forest, Gradient Boosting)
# - K-Nearest Neighbors (KNeighbors)
# - Stochastic Gradient Descent (SGDC)
# - Support Vector Machines (SVM)
# - Logistic Regression

# %% [markdown]
# ### Question 2 - Model Application
# *List three supervised learning models that are appropriate for this problem. For each model chosen*
# - Describe one real-world application in industry where the model can be applied. *(You may need to do a small bit of research for this — give references!)*
# - What are the strengths of the model; when does it perform well?
# - What are the weaknesses of the model; when does it perform poorly?
# - What makes this model a good candidate for the problem, given what you know about the data?

# %% [markdown]
# **Answer: ** According to the scikit-learn algorithm cheat sheet, for a classification algorithm and for samples whose count is less than 100K samples, we should start by Linear SVM.SVC and then KNN and then Ensemble Classifiers. In the following, we will analyze the strengths and weaknesses of each model.
#
# 1. SVM (SVC)
# [Source: "https://www.analyticsvidhya.com/blog/2015/10/understaing-support-vector-machine-example-code/"]
#
# 1.1. Application: SVM is widely used in the classification of images and in hand-written characters recognition
#
# 1.2. Strengths: SVM has a clear margin of separation, is effective in higher dimensions space of features and is memory efficient since it uses a subset of training points in the decision function.
#
# 1.3. Weaknesses: It also doesn’t perform very well, when the data set has more noise i.e. target classes are overlapping. In addition, It doesn’t perform well, when we have large data set because the required training time is higher
#
# 1.4. Why it is a good candidate: Given that the number of samples is not huge and given that we have a considerable amount of features then we should be able to benefit from this algorithm
#
# 2. K-Nearest Neighbors KNN
# [Source: "https://saravananthirumuruganathan.wordpress.com/2010/05/17/a-detailed-introduction-to-k-nearest-neighbor-knn-algorithm/"]
#
# 2.1. Application: It is surprisingly versatile and its applications range from vision to proteins to computational geometry to graphs and so on
#
# 2.2. Strengths: There is practically no training required (known as a lazy algorithm)
#
# 2.3. Weaknesses: We will need more memory than the other classifiers as we always have to refer to all samples during predictions. In addition, Testing is very costly in terms of time.
#
# 2.4. Why it is a good candidate: we don't have a huge number of samples and therefore the available memory is fine for testing and prediction
#
# 3. Ensemble Classifiers
# [Source: "https://en.wikipedia.org/wiki/Ensembles_of_classifiers"]
#
# 3.1. Application: The most known application of ensemble classifiers is the Netflix challenge recommender system. Other examples include malware Intrusion detection, Banking, credit risk, fraud detection, Coronary diseases, …
#
# 3.2. Strengths: Achieves very high boost in accuracy as it improves underlying models
#
# 2.3. Weaknesses: Requires increased storage, computation and decreased comprehensibility
#
# 3.4. Why it is a good candidate: Due to the expected boost in accuracy the I am looking forward to test the perforamnce of the  Ensemble Classifier - Random Forest model

# %% [markdown]
# ### Setup
# Run the code cell below to initialize three helper functions which you can use for training and testing the three supervised learning models you've chosen above. The functions are as follows:
# - `train_classifier` - takes as input a classifier and training data and fits the classifier to the data.
# - `predict_labels` - takes as input a fit classifier, features, and a target labeling and makes predictions using the F<sub>1</sub> score.
# - `train_predict` - takes as input a classifier, and the training and testing data, and performs `train_clasifier` and `predict_labels`.
#  - This function will report the F<sub>1</sub> score for both the training and testing data separately.

# %%
def train_classifier(clf, X_train, y_train):
    ''' Fits a classifier to the training data. '''
    
    # Start the clock, train the classifier, then stop the clock
    start = time()
    clf.fit(X_train, y_train)
    end = time()
    
    # Print the results
    print "Trained model in {:.4f} seconds".format(end - start)

    
def predict_labels(clf, features, target):
    ''' Makes predictions using a fit classifier based on F1 score. '''
    
    # Start the clock, make predictions, then stop the clock
    start = time()
    y_pred = clf.predict(features)
    end = time()
    
    # Print and return results
    print "Made predictions in {:.4f} seconds.".format(end - start)
    return f1_score(target.values, y_pred, pos_label='yes')


def train_predict(clf, X_train, y_train, X_test, y_test):
    ''' Train and predict using a classifer based on F1 score. '''
    
    # Indicate the classifier and the training set size
    print "Training a {} using a training set size of {}. . .".format(clf.__class__.__name__, len(X_train))
    
    # Train the classifier
    train_classifier(clf, X_train, y_train)
    
    # Print the results of prediction for both training and testing
    print "F1 score for training set: {:.4f}.".format(predict_labels(clf, X_train, y_train))
    print "F1 score for test set: {:.4f}.".format(predict_labels(clf, X_test, y_test))

# %% [markdown]
# ### Implementation: Model Performance Metrics
# With the predefined functions above, you will now import the three supervised learning models of your choice and run the `train_predict` function for each one. Remember that you will need to train and predict on each classifier for three different training set sizes: 100, 200, and 300. Hence, you should expect to have 9 different outputs below — 3 for each model using the varying training set sizes. In the following code cell, you will need to implement the following:
# - Import the three supervised learning models you've discussed in the previous section.
# - Initialize the three models and store them in `clf_A`, `clf_B`, and `clf_C`.
#  - Use a `random_state` for each model you use, if provided.
#  - **Note:** Use the default settings for each model — you will tune one specific model in a later section.
# - Create the different training set sizes to be used to train each model.
#  - *Do not reshuffle and resplit the data! The new training points should be drawn from `X_train` and `y_train`.*
# - Fit each model with each training set size and make predictions on the test set (9 in total).
# **Note:** Three tables are provided after the following code cell which can be used to store your results.

# %%
# TODO: Import the three supervised learning models from sklearn
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.ensemble import RandomForestClassifier

# TODO: Initialize the three models
clf_A = SVC()
clf_B = KNeighborsClassifier()
clf_C = RandomForestClassifier()


# TODO: Set up the training set sizes
X_train_100 = X_train[0:100]
y_train_100 = y_train[0:100]

X_train_200 = X_train[0:200]
y_train_200 = y_train[0:200]

X_train_300 = X_train[0:300]
y_train_300 = y_train[0:300]

# TODO: Execute the 'train_predict' function for each classifier and each training set size
# train_predict(clf, X_train, y_train, X_test, y_test)

# SVM Classifier (SVC)
print "----- SVC -----"
train_predict(clf_A, X_train_100, y_train_100, X_test, y_test)
train_predict(clf_A, X_train_200, y_train_200, X_test, y_test)
train_predict(clf_A, X_train_300, y_train_300, X_test, y_test)
print "---------------"

#KNN Classifier
print "----- KNN -----"
train_predict(clf_B, X_train_100, y_train_100, X_test, y_test)
train_predict(clf_B, X_train_200, y_train_200, X_test, y_test)
train_predict(clf_B, X_train_300, y_train_300, X_test, y_test)
print "---------------"

#Ensemble Classifier (Random Forest)
print "----- RnF -----"
train_predict(clf_C, X_train_100, y_train_100, X_test, y_test)
train_predict(clf_C, X_train_200, y_train_200, X_test, y_test)
train_predict(clf_C, X_train_300, y_train_300, X_test, y_test)
print "---------------"
# Out:
# ----- SVC -----
# Training a SVC using a training set size of 100. . .
# Trained model in 0.0090 seconds
# Made predictions in 0.0060 seconds.
# F1 score for training set: 0.8500.
# Made predictions in 0.0150 seconds.
# F1 score for test set: 0.8129.
# Training a SVC using a training set size of 200. . .
# Trained model in 0.0220 seconds
# Made predictions in 0.0180 seconds.
# F1 score for training set: 0.8562.
# Made predictions in 0.0120 seconds.
# F1 score for test set: 0.8000.
# Training a SVC using a training set size of 300. . .
# Trained model in 0.0770 seconds
# Made predictions in 0.0480 seconds.
# F1 score for training set: 0.8577.
# Made predictions in 0.0220 seconds.
# F1 score for test set: 0.8108.
# ---------------
# ----- KNN -----
# Training a KNeighborsClassifier using a training set size of 100. . .
# Trained model in 0.0070 seconds
# Made predictions in 0.0120 seconds.
# F1 score for training set: 0.7778.
# Made predictions in 0.0190 seconds.
# F1 score for test set: 0.7368.
# Training a KNeighborsClassifier using a training set size of 200. . .
# Trained model in 0.0050 seconds
# Made predictions in 0.0280 seconds.
# F1 score for training set: 0.8627.
# Made predictions in 0.0200 seconds.
# F1 score for test set: 0.7714.
# Training a KNeighborsClassifier using a training set size of 300. . .
# Trained model in 0.0230 seconds
# Made predictions in 0.0540 seconds.
# F1 score for training set: 0.8694.
# Made predictions in 0.0340 seconds.
# F1 score for test set: 0.7313.
# ---------------
# ----- RnF -----
# Training a RandomForestClassifier using a training set size of 100. . .
# Trained model in 0.3070 seconds
# Made predictions in 0.0590 seconds.
# F1 score for training set: 0.9927.
# Made predictions in 0.0380 seconds.
# F1 score for test set: 0.6818.
# Training a RandomForestClassifier using a training set size of 200. . .
# Trained model in 0.1690 seconds
# Made predictions in 0.0430 seconds.
# F1 score for training set: 0.9745.
# Made predictions in 0.0570 seconds.
# F1 score for test set: 0.7761.
# Training a RandomForestClassifier using a training set size of 300. . .
# Trained model in 0.1890 seconds
# Made predictions in 0.0490 seconds.
# F1 score for training set: 0.9950.
# Made predictions in 0.0990 seconds.
# F1 score for test set: 0.6772.
# ---------------

# %%
# Testing Ensemble Learner / Adaboost
from sklearn.ensemble import AdaBoostClassifier

# TODO: Initialize the three models
clf_D = AdaBoostClassifier()


# TODO: Execute the 'train_predict' function for each classifier and each training set size
# train_predict(clf, X_train, y_train, X_test, y_test)

# Adaboost
print "----- Ada -----"
train_predict(clf_D, X_train_100, y_train_100, X_test, y_test)
train_predict(clf_D, X_train_200, y_train_200, X_test, y_test)
train_predict(clf_D, X_train_300, y_train_300, X_test, y_test)
# Out:
# ----- Ada -----
# Training a AdaBoostClassifier using a training set size of 100. . .
# Trained model in 0.8430 seconds
# Made predictions in 0.0210 seconds.
# F1 score for training set: 0.9706.
# Made predictions in 0.0200 seconds.
# F1 score for test set: 0.6719.
# Training a AdaBoostClassifier using a training set size of 200. . .
# Trained model in 0.7210 seconds
# Made predictions in 0.0280 seconds.
# F1 score for training set: 0.8784.
# Made predictions in 0.0210 seconds.
# F1 score for test set: 0.7429.
# Training a AdaBoostClassifier using a training set size of 300. . .
# Trained model in 0.7780 seconds
# Made predictions in 0.0350 seconds.
# F1 score for training set: 0.8598.
# Made predictions in 0.0270 seconds.
# F1 score for test set: 0.7218.

# %% [markdown]
# ### Tabular Results
# Edit the cell below to see how a table can be designed in [Markdown](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet#tables). You can record your results from above in the tables provided.

# %% [markdown]
# ** Classifer 1 - Support Vector Machines (SVC)**
#
# | Training Set Size | Training Time | Prediction Time (test) | F1 Score (train) | F1 Score (test) |
# | :---------------: | :---------------------: | :--------------------: | :--------------: | :-------------: |
# | 100               |         0.0090          |        0.0150          |      0.8500      |    0.8129       |
# | 200               |         0.0220          |        0.0120          |      0.8562      |    0.8000       |
# | 300               |         0.0770          |        0.0220          |      0.8577      |    0.8108       |
#
# ** Classifer 2 - K-Nearest Neighbors**
#
# | Training Set Size | Training Time | Prediction Time (test) | F1 Score (train) | F1 Score (test) |
# | :---------------: | :---------------------: | :--------------------: | :--------------: | :-------------: |
# | 100               |         0.007           |         0.0190          |      0.7778      |    0.7368       |
# | 200               |         0.005           |         0.0200          |      0.8627      |    0.7714       |
# | 300               |         0.023           |         0.0340          |      0.8694      |    0.7313       |
#
# ** Classifer 3 - Ensemble - Random Forest Classifier**
#
# | Training Set Size | Training Time | Prediction Time (test) | F1 Score (train) | F1 Score (test) |
# | :---------------: | :---------------------: | :--------------------: | :--------------: | :-------------: |
# | 100               |        0.3070           |        0.0380          |      0.9927            |     0.6818            |
# | 200               |        0.1690           |        0.0570          |      0.9745            |     0.7761            |
# | 300               |        0.1890           |        0.0990          |      0.9950            |     0.6772            |

# %% [markdown]
# ## Choosing the Best Model
# In this final section, you will choose from the three supervised learning models the *best* model to use on the student data. You will then perform a grid search optimization for the model over the entire training set (`X_train` and `y_train`) by tuning at least one parameter to improve upon the untuned model's F<sub>1</sub> score.

# %% [markdown]
# ### Question 3 - Choosing the Best Model
# *Based on the experiments you performed earlier, in one to two paragraphs, explain to the board of supervisors what single model you chose as the best model. Which model is generally the most appropriate based on the available data, limited resources, cost, and performance?*

# %% [markdown]
# **Answer: ** From the above tabular table, I can clearly see that the best model is the Support Vector Classifier (SVC). The reason for choosing this model is due to:
#
# 1. Performance: The accuracy on test data is much better than the other 2 models (achieving more than 80% of F1 score for all training counts)
#
# 2. Prediction Time: The prediction time for SVC is clearly much better than the other 2 models in which we achived a record breaking timing of 0.12 sec for 200 training samples with great difference from the next best timing in the other models
#
# 3. Resources: The highest resource consumption model is the KNN model in which we should always store the test and training points to predict the outcome of new points. This will require a good amount of memory in comparison to the other models in which we will only need to store the model and forget all training and test points. Therefore, KNN is not advisable to be used in case of limited resources.
#
# 4. Cost: From the above matrix, it is clearly shown that the training and prediction time for Ensemble algorithm are the highest due to the fact that ensemble algorithm are iterative in nature which will require high CPU resources which is very costy in terms of resources. The next model in terms of resources cost is the KNN since it is known as a lazy algorithm in which the algorithm performs the prediction calculations when asked to and for each new data point which will consume a lot of CPU resources. Therefore, the best model in terms of cost efficiency is the SVC.

# %% [markdown]
# ### Question 4 - Model in Layman's Terms
# *In one to two paragraphs, explain to the board of directors in layman's terms how the final model chosen is supposed to work. Be sure that you are describing the major qualities of the model, such as how the model is trained and how the model makes a prediction. Avoid using advanced mathematical or technical jargon, such as describing equations or discussing the algorithm implementation.*

# %% [markdown]
# **Answer: **
#
# Training: The model that we selected (Support Vector Machines Classifier) is very simple to describe as during training, the algorithm separates data points of different classes by drawing a border line (Hyperplane). This border line is selected in a way that it achieves maximum distance from datapoints of different classes. This will maximize the robustness of the results.
#
# Prediction: Once the border line (Hyperplane) is selected, we forget all training data points and whenever a test data point is given, the algorithm will simple check if the data point is above or below the hyperplane and accordingly associate it to a corresponding class.

# %% [markdown]
# ### Implementation: Model Tuning
# Fine tune the chosen model. Use grid search (`GridSearchCV`) with at least one important parameter tuned with at least 3 different values. You will need to use the entire training set for this. In the code cell below, you will need to implement the following:
# - Import [`sklearn.grid_search.GridSearchCV`](http://scikit-learn.org/0.17/modules/generated/sklearn.grid_search.GridSearchCV.html) and [`sklearn.metrics.make_scorer`](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.make_scorer.html).
# - Create a dictionary of parameters you wish to tune for the chosen model.
#  - Example: `parameters = {'parameter' : [list of values]}`.
# - Initialize the classifier you've chosen and store it in `clf`.
# - Create the F<sub>1</sub> scoring function using `make_scorer` and store it in `f1_scorer`.
#  - Set the `pos_label` parameter to the correct value!
# - Perform grid search on the classifier `clf` using `f1_scorer` as the scoring method, and store it in `grid_obj`.
# - Fit the grid search object to the training data (`X_train`, `y_train`), and store it in `grid_obj`.

# %%
# TODO: Import 'GridSearchCV' and 'make_scorer'
# parameters = {'criterion':('entropy', 'gini'), 'splitter':('best', 'random'), 'max_depth':[2,3,4,5,6,7,8,9]}
# est = tree.DecisionTreeClassifier()
# clf2 = GridSearchCV(est, parameters)
# clf2.fit(titanic_train, titanic_train_survived)
# acc2 = accuracy_score(titanic_cv_survived, clf2.predict(titanic_cv))

from sklearn.grid_search import GridSearchCV
from sklearn.metrics import make_scorer 


# TODO: Create the parameters list you wish to tune
parameters = {'C':[0.1, 0.5, 1, 2, 50, 100], 'kernel':('linear', 'poly', 'rbf', 'sigmoid'), 'degree':[1,2,3,4]}

# TODO: Initialize the classifier
clf = SVC()

# TODO: Make an f1 scoring function using 'make_scorer' 
f1_scorer = make_scorer(f1_score, pos_label='yes')

# TODO: Perform grid search on the classifier using the f1_scorer as the scoring method
grid_obj = GridSearchCV(estimator=clf, param_grid=parameters, scoring=f1_scorer, verbose=10)

# TODO: Fit the grid search object to the training data and find the optimal parameters
grid_obj = grid_obj.fit(X_train, y_train)

# Get the estimator
clf = grid_obj.best_estimator_

# Report the final F1 score for training and testing after parameter tuning
print "Tuned model has a training F1 score of {:.4f}.".format(predict_labels(clf, X_train, y_train))
print "Tuned model has a testing F1 score of {:.4f}.".format(predict_labels(clf, X_test, y_test))
# Out:
# Fitting 3 folds for each of 96 candidates, totalling 288 fits
# [CV] kernel=linear, C=0.1, degree=1 ..................................
# [CV] ......... kernel=linear, C=0.1, degree=1, score=0.805195 -   0.0s
# [CV] kernel=linear, C=0.1, degree=1 ..................................
# [CV] ......... kernel=linear, C=0.1, degree=1, score=0.807947 -   0.0s
# [CV] kernel=linear, C=0.1, degree=1 ..................................
# [CV] ......... kernel=linear, C=0.1, degree=1, score=0.838710 -   0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [CV] kernel=poly, C=0.1, degree=1 ....................................
# [CV] ........... kernel=poly, C=0.1, degree=1, score=0.804734 -   0.0s
# [CV] kernel=poly, C=0.1, degree=1 ....................................
# [CV] ........... kernel=poly, C=0.1, degree=1, score=0.802395 -   0.0s
# [CV] kernel=poly, C=0.1, degree=1 ....................................
# [CV] ........... kernel=poly, C=0.1, degree=1, score=0.807229 -   0.0s
# [CV] kernel=rbf, C=0.1, degree=1 .....................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.3s remaining:    0.0s
# [CV] ............ kernel=rbf, C=0.1, degree=1, score=0.804734 -   0.0s
# [CV] kernel=rbf, C=0.1, degree=1 .....................................
# [CV] ............ kernel=rbf, C=0.1, degree=1, score=0.802395 -   0.0s
# [CV] kernel=rbf, C=0.1, degree=1 .....................................
# [CV] ............ kernel=rbf, C=0.1, degree=1, score=0.807229 -   0.0s
# [CV] kernel=sigmoid, C=0.1, degree=1 .................................
# [CV] ........ kernel=sigmoid, C=0.1, degree=1, score=0.804734 -   0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.5s remaining:    0.0s
# [CV] kernel=sigmoid, C=0.1, degree=1 .................................
# [CV] ........ kernel=sigmoid, C=0.1, degree=1, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=0.1, degree=1 .................................
# [CV] ........ kernel=sigmoid, C=0.1, degree=1, score=0.807229 -   0.0s
# [CV] kernel=linear, C=0.1, degree=2 ..................................
# [CV] ......... kernel=linear, C=0.1, degree=2, score=0.805195 -   0.0s
# [CV] kernel=linear, C=0.1, degree=2 ..................................
# [CV] ......... kernel=linear, C=0.1, degree=2, score=0.807947 -   0.0s
# [CV] kernel=linear, C=0.1, degree=2 ..................................
# [CV] ......... kernel=linear, C=0.1, degree=2, score=0.838710 -   0.0s
# [CV] kernel=poly, C=0.1, degree=2 ....................................
# [CV] ........... kernel=poly, C=0.1, degree=2, score=0.812903 -   0.0s
# [CV] kernel=poly, C=0.1, degree=2 ....................................
# [CV] ........... kernel=poly, C=0.1, degree=2, score=0.805031 -   0.0s
# [CV] kernel=poly, C=0.1, degree=2 ....................................
# [CV] ........... kernel=poly, C=0.1, degree=2, score=0.835443 -   0.0s
# [CV] kernel=rbf, C=0.1, degree=2 .....................................
# [CV] ............ kernel=rbf, C=0.1, degree=2, score=0.804734 -   0.0s
# [CV] kernel=rbf, C=0.1, degree=2 .....................................
# [CV] ............ kernel=rbf, C=0.1, degree=2, score=0.802395 -   0.0s
# [CV] kernel=rbf, C=0.1, degree=2 .....................................
# [CV] ............ kernel=rbf, C=0.1, degree=2, score=0.807229 -   0.0s
# [CV] kernel=sigmoid, C=0.1, degree=2 .................................
# [CV] ........ kernel=sigmoid, C=0.1, degree=2, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=0.1, degree=2 .................................
# [CV] ........ kernel=sigmoid, C=0.1, degree=2, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=0.1, degree=2 .................................
# [CV] ........ kernel=sigmoid, C=0.1, degree=2, score=0.807229 -   0.0s
# [CV] kernel=linear, C=0.1, degree=3 ..................................
# [CV] ......... kernel=linear, C=0.1, degree=3, score=0.805195 -   0.0s
# [CV] kernel=linear, C=0.1, degree=3 ..................................
# [CV] ......... kernel=linear, C=0.1, degree=3, score=0.807947 -   0.0s
# [CV] kernel=linear, C=0.1, degree=3 ..................................
# [CV] ......... kernel=linear, C=0.1, degree=3, score=0.838710 -   0.0s
# [CV] kernel=poly, C=0.1, degree=3 ....................................
# [CV] ........... kernel=poly, C=0.1, degree=3, score=0.797203 -   0.0s
# [CV] kernel=poly, C=0.1, degree=3 ....................................
# [CV] ........... kernel=poly, C=0.1, degree=3, score=0.735294 -   0.0s
# [CV] kernel=poly, C=0.1, degree=3 ....................................
# [CV] ........... kernel=poly, C=0.1, degree=3, score=0.788321 -   0.0s
# [CV] kernel=rbf, C=0.1, degree=3 .....................................
# [CV] ............ kernel=rbf, C=0.1, degree=3, score=0.804734 -   0.0s
# [CV] kernel=rbf, C=0.1, degree=3 .....................................
# [CV] ............ kernel=rbf, C=0.1, degree=3, score=0.802395 -   0.0s
# [CV] kernel=rbf, C=0.1, degree=3 .....................................
# [CV] ............ kernel=rbf, C=0.1, degree=3, score=0.807229 -   0.0s
# [CV] kernel=sigmoid, C=0.1, degree=3 .................................
# [CV] ........ kernel=sigmoid, C=0.1, degree=3, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=0.1, degree=3 .................................
# [CV] ........ kernel=sigmoid, C=0.1, degree=3, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=0.1, degree=3 .................................
# [CV] ........ kernel=sigmoid, C=0.1, degree=3, score=0.807229 -   0.0s
# [CV] kernel=linear, C=0.1, degree=4 ..................................
# [CV] ......... kernel=linear, C=0.1, degree=4, score=0.805195 -   0.0s
# [CV] kernel=linear, C=0.1, degree=4 ..................................
# [CV] ......... kernel=linear, C=0.1, degree=4, score=0.807947 -   0.0s
# [CV] kernel=linear, C=0.1, degree=4 ..................................
# [CV] ......... kernel=linear, C=0.1, degree=4, score=0.838710 -   0.0s
# [CV] kernel=poly, C=0.1, degree=4 ....................................
# [CV] ........... kernel=poly, C=0.1, degree=4, score=0.715328 -   0.0s
# [CV] kernel=poly, C=0.1, degree=4 ....................................
# [CV] ........... kernel=poly, C=0.1, degree=4, score=0.692308 -   0.0s
# [CV] kernel=poly, C=0.1, degree=4 ....................................
# [CV] ........... kernel=poly, C=0.1, degree=4, score=0.692913 -   0.0s
# [CV] kernel=rbf, C=0.1, degree=4 .....................................
# [CV] ............ kernel=rbf, C=0.1, degree=4, score=0.804734 -   0.0s
# [CV] kernel=rbf, C=0.1, degree=4 .....................................
# [CV] ............ kernel=rbf, C=0.1, degree=4, score=0.802395 -   0.0s
# [CV] kernel=rbf, C=0.1, degree=4 .....................................
# [CV] ............ kernel=rbf, C=0.1, degree=4, score=0.807229 -   0.0s
# [CV] kernel=sigmoid, C=0.1, degree=4 .................................
# [CV] ........ kernel=sigmoid, C=0.1, degree=4, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=0.1, degree=4 .................................
# [CV] ........ kernel=sigmoid, C=0.1, degree=4, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=0.1, degree=4 .................................
# [CV] ........ kernel=sigmoid, C=0.1, degree=4, score=0.807229 -   0.0s
# [CV] kernel=linear, C=0.5, degree=1 ..................................
# [CV] ......... kernel=linear, C=0.5, degree=1, score=0.786207 -   0.0s
# [CV] kernel=linear, C=0.5, degree=1 ..................................
# [CV] ......... kernel=linear, C=0.5, degree=1, score=0.769231 -   0.0s
# [CV] kernel=linear, C=0.5, degree=1 ..................................
# [CV] ......... kernel=linear, C=0.5, degree=1, score=0.853147 -   0.0s
# [CV] kernel=poly, C=0.5, degree=1 ....................................
# [CV] ........... kernel=poly, C=0.5, degree=1, score=0.809524 -   0.0s
# [CV] kernel=poly, C=0.5, degree=1 ....................................
# [CV] ........... kernel=poly, C=0.5, degree=1, score=0.807229 -   0.0s
# [CV] kernel=poly, C=0.5, degree=1 ....................................
# [CV] ........... kernel=poly, C=0.5, degree=1, score=0.807229 -   0.0s
# [CV] kernel=rbf, C=0.5, degree=1 .....................................
# [CV] ............ kernel=rbf, C=0.5, degree=1, score=0.804734 -   0.0s
# [CV] kernel=rbf, C=0.5, degree=1 .....................................
# [CV] ............ kernel=rbf, C=0.5, degree=1, score=0.807229 -   0.0s
# [CV] kernel=rbf, C=0.5, degree=1 .....................................
# [CV] ............ kernel=rbf, C=0.5, degree=1, score=0.807229 -   0.0s
# [CV] kernel=sigmoid, C=0.5, degree=1 .................................
# [CV] ........ kernel=sigmoid, C=0.5, degree=1, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=0.5, degree=1 .................................
# [CV] ........ kernel=sigmoid, C=0.5, degree=1, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=0.5, degree=1 .................................
# [CV] ........ kernel=sigmoid, C=0.5, degree=1, score=0.807229 -   0.0s
# [CV] kernel=linear, C=0.5, degree=2 ..................................
# [CV] ......... kernel=linear, C=0.5, degree=2, score=0.786207 -   0.0s
# [CV] kernel=linear, C=0.5, degree=2 ..................................
# [CV] ......... kernel=linear, C=0.5, degree=2, score=0.769231 -   0.0s
# [CV] kernel=linear, C=0.5, degree=2 ..................................
# [CV] ......... kernel=linear, C=0.5, degree=2, score=0.853147 -   0.0s
# [CV] kernel=poly, C=0.5, degree=2 ....................................
# [CV] ........... kernel=poly, C=0.5, degree=2, score=0.810811 -   0.0s
# [CV] kernel=poly, C=0.5, degree=2 ....................................
# [CV] ........... kernel=poly, C=0.5, degree=2, score=0.797297 -   0.0s
# [CV] kernel=poly, C=0.5, degree=2 ....................................
# [CV] ........... kernel=poly, C=0.5, degree=2, score=0.841379 -   0.0s
# [CV] kernel=rbf, C=0.5, degree=2 .....................................
# [CV] ............ kernel=rbf, C=0.5, degree=2, score=0.804734 -   0.0s
# [CV] kernel=rbf, C=0.5, degree=2 .....................................
# [CV] ............ kernel=rbf, C=0.5, degree=2, score=0.807229 -   0.0s
# [CV] kernel=rbf, C=0.5, degree=2 .....................................
# [CV] ............ kernel=rbf, C=0.5, degree=2, score=0.807229 -   0.0s
# [CV] kernel=sigmoid, C=0.5, degree=2 .................................
# [CV] ........ kernel=sigmoid, C=0.5, degree=2, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=0.5, degree=2 .................................
# [CV] ........ kernel=sigmoid, C=0.5, degree=2, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=0.5, degree=2 .................................
# [CV] ........ kernel=sigmoid, C=0.5, degree=2, score=0.807229 -   0.0s
# [CV] kernel=linear, C=0.5, degree=3 ..................................
# [CV] ......... kernel=linear, C=0.5, degree=3, score=0.786207 -   0.0s
# [CV] kernel=linear, C=0.5, degree=3 ..................................
# [CV] ......... kernel=linear, C=0.5, degree=3, score=0.769231 -   0.0s
# [CV] kernel=linear, C=0.5, degree=3 ..................................
# [CV] ......... kernel=linear, C=0.5, degree=3, score=0.853147 -   0.0s
# [CV] kernel=poly, C=0.5, degree=3 ....................................
# [CV] ........... kernel=poly, C=0.5, degree=3, score=0.705882 -   0.0s
# [CV] kernel=poly, C=0.5, degree=3 ....................................
# [CV] ........... kernel=poly, C=0.5, degree=3, score=0.676471 -   0.0s
# [CV] kernel=poly, C=0.5, degree=3 ....................................
# [CV] ........... kernel=poly, C=0.5, degree=3, score=0.677686 -   0.0s
# [CV] kernel=rbf, C=0.5, degree=3 .....................................
# [CV] ............ kernel=rbf, C=0.5, degree=3, score=0.804734 -   0.0s
# [CV] kernel=rbf, C=0.5, degree=3 .....................................
# [CV] ............ kernel=rbf, C=0.5, degree=3, score=0.807229 -   0.0s
# [CV] kernel=rbf, C=0.5, degree=3 .....................................
# [CV] ............ kernel=rbf, C=0.5, degree=3, score=0.807229 -   0.0s
# [CV] kernel=sigmoid, C=0.5, degree=3 .................................
# [CV] ........ kernel=sigmoid, C=0.5, degree=3, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=0.5, degree=3 .................................
# [CV] ........ kernel=sigmoid, C=0.5, degree=3, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=0.5, degree=3 .................................
# [CV] ........ kernel=sigmoid, C=0.5, degree=3, score=0.807229 -   0.0s
# [CV] kernel=linear, C=0.5, degree=4 ..................................
# [CV] ......... kernel=linear, C=0.5, degree=4, score=0.786207 -   0.0s
# [CV] kernel=linear, C=0.5, degree=4 ..................................
# [CV] ......... kernel=linear, C=0.5, degree=4, score=0.769231 -   0.0s
# [CV] kernel=linear, C=0.5, degree=4 ..................................
# [CV] ......... kernel=linear, C=0.5, degree=4, score=0.853147 -   0.0s
# [CV] kernel=poly, C=0.5, degree=4 ....................................
# [CV] ........... kernel=poly, C=0.5, degree=4, score=0.715328 -   0.0s
# [CV] kernel=poly, C=0.5, degree=4 ....................................
# [CV] ........... kernel=poly, C=0.5, degree=4, score=0.692308 -   0.0s
# [CV] kernel=poly, C=0.5, degree=4 ....................................
# [CV] ........... kernel=poly, C=0.5, degree=4, score=0.688525 -   0.0s
# [CV] kernel=rbf, C=0.5, degree=4 .....................................
# [CV] ............ kernel=rbf, C=0.5, degree=4, score=0.804734 -   0.0s
# [CV] kernel=rbf, C=0.5, degree=4 .....................................
# [CV] ............ kernel=rbf, C=0.5, degree=4, score=0.807229 -   0.0s
# [CV] kernel=rbf, C=0.5, degree=4 .....................................
# [CV] ............ kernel=rbf, C=0.5, degree=4, score=0.807229 -   0.0s
# [CV] kernel=sigmoid, C=0.5, degree=4 .................................
# [CV] ........ kernel=sigmoid, C=0.5, degree=4, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=0.5, degree=4 .................................
# [CV] ........ kernel=sigmoid, C=0.5, degree=4, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=0.5, degree=4 .................................
# [CV] ........ kernel=sigmoid, C=0.5, degree=4, score=0.807229 -   0.0s
# [CV] kernel=linear, C=1, degree=1 ....................................
# [CV] ........... kernel=linear, C=1, degree=1, score=0.760563 -   0.0s
# [CV] kernel=linear, C=1, degree=1 ....................................
# [CV] ........... kernel=linear, C=1, degree=1, score=0.769231 -   0.0s
# [CV] kernel=linear, C=1, degree=1 ....................................
# [CV] ........... kernel=linear, C=1, degree=1, score=0.842857 -   0.0s
# [CV] kernel=poly, C=1, degree=1 ......................................
# [CV] ............. kernel=poly, C=1, degree=1, score=0.807453 -   0.0s
# [CV] kernel=poly, C=1, degree=1 ......................................
# [CV] ............. kernel=poly, C=1, degree=1, score=0.807453 -   0.0s
# [CV] kernel=poly, C=1, degree=1 ......................................
# [CV] ............. kernel=poly, C=1, degree=1, score=0.832298 -   0.0s
# [CV] kernel=rbf, C=1, degree=1 .......................................
# [CV] .............. kernel=rbf, C=1, degree=1, score=0.827160 -   0.0s
# [CV] kernel=rbf, C=1, degree=1 .......................................
# [CV] .............. kernel=rbf, C=1, degree=1, score=0.802469 -   0.0s
# [CV] kernel=rbf, C=1, degree=1 .......................................
# [CV] .............. kernel=rbf, C=1, degree=1, score=0.794872 -   0.0s
# [CV] kernel=sigmoid, C=1, degree=1 ...................................
# [CV] .......... kernel=sigmoid, C=1, degree=1, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=1, degree=1 ...................................
# [CV] .......... kernel=sigmoid, C=1, degree=1, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=1, degree=1 ...................................
# [CV] .......... kernel=sigmoid, C=1, degree=1, score=0.807229 -   0.0s
# [CV] kernel=linear, C=1, degree=2 ....................................
# [CV] ........... kernel=linear, C=1, degree=2, score=0.760563 -   0.0s
# [CV] kernel=linear, C=1, degree=2 ....................................
# [CV] ........... kernel=linear, C=1, degree=2, score=0.769231 -   0.0s
# [CV] kernel=linear, C=1, degree=2 ....................................
# [CV] ........... kernel=linear, C=1, degree=2, score=0.842857 -   0.0s
# [CV] kernel=poly, C=1, degree=2 ......................................
# [CV] ............. kernel=poly, C=1, degree=2, score=0.797203 -   0.0s
# [CV] kernel=poly, C=1, degree=2 ......................................
# [CV] ............. kernel=poly, C=1, degree=2, score=0.783217 -   0.0s
# [CV] kernel=poly, C=1, degree=2 ......................................
# [CV] ............. kernel=poly, C=1, degree=2, score=0.836879 -   0.0s
# [CV] kernel=rbf, C=1, degree=2 .......................................
# [CV] .............. kernel=rbf, C=1, degree=2, score=0.827160 -   0.0s
# [CV] kernel=rbf, C=1, degree=2 .......................................
# [CV] .............. kernel=rbf, C=1, degree=2, score=0.802469 -   0.0s
# [CV] kernel=rbf, C=1, degree=2 .......................................
# [CV] .............. kernel=rbf, C=1, degree=2, score=0.794872 -   0.0s
# [CV] kernel=sigmoid, C=1, degree=2 ...................................
# [CV] .......... kernel=sigmoid, C=1, degree=2, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=1, degree=2 ...................................
# [CV] .......... kernel=sigmoid, C=1, degree=2, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=1, degree=2 ...................................
# [CV] .......... kernel=sigmoid, C=1, degree=2, score=0.807229 -   0.0s
# [CV] kernel=linear, C=1, degree=3 ....................................
# [CV] ........... kernel=linear, C=1, degree=3, score=0.760563 -   0.0s
# [CV] kernel=linear, C=1, degree=3 ....................................
# [CV] ........... kernel=linear, C=1, degree=3, score=0.769231 -   0.0s
# [CV] kernel=linear, C=1, degree=3 ....................................
# [CV] ........... kernel=linear, C=1, degree=3, score=0.842857 -   0.0s
# [CV] kernel=poly, C=1, degree=3 ......................................
# [CV] ............. kernel=poly, C=1, degree=3, score=0.696970 -   0.1s
# [CV] kernel=poly, C=1, degree=3 ......................................
# [CV] ............. kernel=poly, C=1, degree=3, score=0.705882 -   0.0s
# [CV] kernel=poly, C=1, degree=3 ......................................
# [CV] ............. kernel=poly, C=1, degree=3, score=0.655738 -   0.1s
# [CV] kernel=rbf, C=1, degree=3 .......................................
# [CV] .............. kernel=rbf, C=1, degree=3, score=0.827160 -   0.0s
# [CV] kernel=rbf, C=1, degree=3 .......................................
# [CV] .............. kernel=rbf, C=1, degree=3, score=0.802469 -   0.0s
# [CV] kernel=rbf, C=1, degree=3 .......................................
# [CV] .............. kernel=rbf, C=1, degree=3, score=0.794872 -   0.0s
# [CV] kernel=sigmoid, C=1, degree=3 ...................................
# [CV] .......... kernel=sigmoid, C=1, degree=3, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=1, degree=3 ...................................
# [CV] .......... kernel=sigmoid, C=1, degree=3, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=1, degree=3 ...................................
# [CV] .......... kernel=sigmoid, C=1, degree=3, score=0.807229 -   0.0s
# [CV] kernel=linear, C=1, degree=4 ....................................
# [CV] ........... kernel=linear, C=1, degree=4, score=0.760563 -   0.0s
# [CV] kernel=linear, C=1, degree=4 ....................................
# [CV] ........... kernel=linear, C=1, degree=4, score=0.769231 -   0.0s
# [CV] kernel=linear, C=1, degree=4 ....................................
# [CV] ........... kernel=linear, C=1, degree=4, score=0.842857 -   0.0s
# [CV] kernel=poly, C=1, degree=4 ......................................
# [CV] ............. kernel=poly, C=1, degree=4, score=0.715328 -   0.0s
# [CV] kernel=poly, C=1, degree=4 ......................................
# [CV] ............. kernel=poly, C=1, degree=4, score=0.692308 -   0.0s
# [CV] kernel=poly, C=1, degree=4 ......................................
# [CV] ............. kernel=poly, C=1, degree=4, score=0.688525 -   0.0s
# [CV] kernel=rbf, C=1, degree=4 .......................................
# [CV] .............. kernel=rbf, C=1, degree=4, score=0.827160 -   0.0s
# [CV] kernel=rbf, C=1, degree=4 .......................................
# [CV] .............. kernel=rbf, C=1, degree=4, score=0.802469 -   0.0s
# [CV] kernel=rbf, C=1, degree=4 .......................................
# [CV] .............. kernel=rbf, C=1, degree=4, score=0.794872 -   0.0s
# [CV] kernel=sigmoid, C=1, degree=4 ...................................
# [CV] .......... kernel=sigmoid, C=1, degree=4, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=1, degree=4 ...................................
# [CV] .......... kernel=sigmoid, C=1, degree=4, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=1, degree=4 ...................................
# [CV] .......... kernel=sigmoid, C=1, degree=4, score=0.807229 -   0.0s
# [CV] kernel=linear, C=2, degree=1 ....................................
# [CV] ........... kernel=linear, C=2, degree=1, score=0.760563 -   0.0s
# [CV] kernel=linear, C=2, degree=1 ....................................
# [CV] ........... kernel=linear, C=2, degree=1, score=0.765957 -   0.0s
# [CV] kernel=linear, C=2, degree=1 ....................................
# [CV] ........... kernel=linear, C=2, degree=1, score=0.834532 -   0.5s
# [CV] kernel=poly, C=2, degree=1 ......................................
# [CV] ............. kernel=poly, C=2, degree=1, score=0.820513 -   0.0s
# [CV] kernel=poly, C=2, degree=1 ......................................
# [CV] ............. kernel=poly, C=2, degree=1, score=0.805031 -   0.0s
# [CV] kernel=poly, C=2, degree=1 ......................................
# [CV] ............. kernel=poly, C=2, degree=1, score=0.848101 -   0.0s
# [CV] kernel=rbf, C=2, degree=1 .......................................
# [CV] .............. kernel=rbf, C=2, degree=1, score=0.802632 -   0.0s
# [CV] kernel=rbf, C=2, degree=1 .......................................
# [CV] .............. kernel=rbf, C=2, degree=1, score=0.802548 -   0.0s
# [CV] kernel=rbf, C=2, degree=1 .......................................
# [CV] .............. kernel=rbf, C=2, degree=1, score=0.810458 -   0.0s
# [CV] kernel=sigmoid, C=2, degree=1 ...................................
# [CV] .......... kernel=sigmoid, C=2, degree=1, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=2, degree=1 ...................................
# [CV] .......... kernel=sigmoid, C=2, degree=1, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=2, degree=1 ...................................
# [CV] .......... kernel=sigmoid, C=2, degree=1, score=0.807229 -   0.0s
# [CV] kernel=linear, C=2, degree=2 ....................................
# [CV] ........... kernel=linear, C=2, degree=2, score=0.760563 -   0.0s
# [CV] kernel=linear, C=2, degree=2 ....................................
# [CV] ........... kernel=linear, C=2, degree=2, score=0.765957 -   0.0s
# [CV] kernel=linear, C=2, degree=2 ....................................
# [CV] ........... kernel=linear, C=2, degree=2, score=0.834532 -   0.3s
# [CV] kernel=poly, C=2, degree=2 ......................................
# [CV] ............. kernel=poly, C=2, degree=2, score=0.768116 -   0.0s
# [CV] kernel=poly, C=2, degree=2 ......................................
# [CV] ............. kernel=poly, C=2, degree=2, score=0.739130 -   0.0s
# [CV] kernel=poly, C=2, degree=2 ......................................
# [CV] ............. kernel=poly, C=2, degree=2, score=0.788321 -   0.0s
# [CV] kernel=rbf, C=2, degree=2 .......................................
# [CV] .............. kernel=rbf, C=2, degree=2, score=0.802632 -   0.0s
# [CV] kernel=rbf, C=2, degree=2 .......................................
# [CV] .............. kernel=rbf, C=2, degree=2, score=0.802548 -   0.0s
# [CV] kernel=rbf, C=2, degree=2 .......................................
# [CV] .............. kernel=rbf, C=2, degree=2, score=0.810458 -   0.0s
# [CV] kernel=sigmoid, C=2, degree=2 ...................................
# [CV] .......... kernel=sigmoid, C=2, degree=2, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=2, degree=2 ...................................
# [CV] .......... kernel=sigmoid, C=2, degree=2, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=2, degree=2 ...................................
# [CV] .......... kernel=sigmoid, C=2, degree=2, score=0.807229 -   0.0s
# [CV] kernel=linear, C=2, degree=3 ....................................
# [CV] ........... kernel=linear, C=2, degree=3, score=0.760563 -   0.0s
# [CV] kernel=linear, C=2, degree=3 ....................................
# [CV] ........... kernel=linear, C=2, degree=3, score=0.765957 -   0.0s
# [CV] kernel=linear, C=2, degree=3 ....................................
# [CV] ........... kernel=linear, C=2, degree=3, score=0.834532 -   0.3s
# [CV] kernel=poly, C=2, degree=3 ......................................
# [CV] ............. kernel=poly, C=2, degree=3, score=0.701493 -   0.0s
# [CV] kernel=poly, C=2, degree=3 ......................................
# [CV] ............. kernel=poly, C=2, degree=3, score=0.696296 -   0.0s
# [CV] kernel=poly, C=2, degree=3 ......................................
# [CV] ............. kernel=poly, C=2, degree=3, score=0.698413 -   0.0s
# [CV] kernel=rbf, C=2, degree=3 .......................................
# [CV] .............. kernel=rbf, C=2, degree=3, score=0.802632 -   0.0s
# [CV] kernel=rbf, C=2, degree=3 .......................................
# [CV] .............. kernel=rbf, C=2, degree=3, score=0.802548 -   0.0s
# [CV] kernel=rbf, C=2, degree=3 .......................................
# [CV] .............. kernel=rbf, C=2, degree=3, score=0.810458 -   0.0s
# [CV] kernel=sigmoid, C=2, degree=3 ...................................
# [CV] .......... kernel=sigmoid, C=2, degree=3, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=2, degree=3 ...................................
# [CV] .......... kernel=sigmoid, C=2, degree=3, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=2, degree=3 ...................................
# [CV] .......... kernel=sigmoid, C=2, degree=3, score=0.807229 -   0.0s
# [CV] kernel=linear, C=2, degree=4 ....................................
# [CV] ........... kernel=linear, C=2, degree=4, score=0.760563 -   0.0s
# [CV] kernel=linear, C=2, degree=4 ....................................
# [CV] ........... kernel=linear, C=2, degree=4, score=0.765957 -   0.1s
# [CV] kernel=linear, C=2, degree=4 ....................................
# [CV] ........... kernel=linear, C=2, degree=4, score=0.834532 -   0.5s
# [CV] kernel=poly, C=2, degree=4 ......................................
# [CV] ............. kernel=poly, C=2, degree=4, score=0.715328 -   0.0s
# [CV] kernel=poly, C=2, degree=4 ......................................
# [CV] ............. kernel=poly, C=2, degree=4, score=0.692308 -   0.1s
# [CV] kernel=poly, C=2, degree=4 ......................................
# [CV] ............. kernel=poly, C=2, degree=4, score=0.688525 -   0.0s
# [CV] kernel=rbf, C=2, degree=4 .......................................
# [CV] .............. kernel=rbf, C=2, degree=4, score=0.802632 -   0.0s
# [CV] kernel=rbf, C=2, degree=4 .......................................
# [CV] .............. kernel=rbf, C=2, degree=4, score=0.802548 -   0.0s
# [CV] kernel=rbf, C=2, degree=4 .......................................
# [CV] .............. kernel=rbf, C=2, degree=4, score=0.810458 -   0.0s
# [CV] kernel=sigmoid, C=2, degree=4 ...................................
# [CV] .......... kernel=sigmoid, C=2, degree=4, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=2, degree=4 ...................................
# [CV] .......... kernel=sigmoid, C=2, degree=4, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=2, degree=4 ...................................
# [CV] .......... kernel=sigmoid, C=2, degree=4, score=0.807229 -   0.0s
# [CV] kernel=linear, C=50, degree=1 ...................................
# [CV] .......... kernel=linear, C=50, degree=1, score=0.744526 -   3.1s
# [CV] kernel=linear, C=50, degree=1 ...................................
# [CV] .......... kernel=linear, C=50, degree=1, score=0.777778 -   4.5s
# [CV] kernel=linear, C=50, degree=1 ...................................
# [CV] .......... kernel=linear, C=50, degree=1, score=0.826087 -   5.8s
# [CV] kernel=poly, C=50, degree=1 .....................................
# [CV] ............ kernel=poly, C=50, degree=1, score=0.760563 -   0.0s
# [CV] kernel=poly, C=50, degree=1 .....................................
# [CV] ............ kernel=poly, C=50, degree=1, score=0.769231 -   0.0s
# [CV] kernel=poly, C=50, degree=1 .....................................
# [CV] ............ kernel=poly, C=50, degree=1, score=0.842857 -   0.0s
# [CV] kernel=rbf, C=50, degree=1 ......................................
# [CV] ............. kernel=rbf, C=50, degree=1, score=0.744526 -   0.0s
# [CV] kernel=rbf, C=50, degree=1 ......................................
# [CV] ............. kernel=rbf, C=50, degree=1, score=0.751773 -   0.0s
# [CV] kernel=rbf, C=50, degree=1 ......................................
# [CV] ............. kernel=rbf, C=50, degree=1, score=0.775194 -   0.0s
# [CV] kernel=sigmoid, C=50, degree=1 ..................................
# [CV] ......... kernel=sigmoid, C=50, degree=1, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=50, degree=1 ..................................
# [CV] ......... kernel=sigmoid, C=50, degree=1, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=50, degree=1 ..................................
# [CV] ......... kernel=sigmoid, C=50, degree=1, score=0.807229 -   0.0s
# [CV] kernel=linear, C=50, degree=2 ...................................
# [CV] .......... kernel=linear, C=50, degree=2, score=0.744526 -   2.0s
# [CV] kernel=linear, C=50, degree=2 ...................................
# [CV] .......... kernel=linear, C=50, degree=2, score=0.777778 -   1.6s
# [CV] kernel=linear, C=50, degree=2 ...................................
# [CV] .......... kernel=linear, C=50, degree=2, score=0.826087 -   4.9s
# [CV] kernel=poly, C=50, degree=2 .....................................
# [CV] ............ kernel=poly, C=50, degree=2, score=0.671756 -   0.0s
# [CV] kernel=poly, C=50, degree=2 .....................................
# [CV] ............ kernel=poly, C=50, degree=2, score=0.681818 -   0.2s
# [CV] kernel=poly, C=50, degree=2 .....................................
# [CV] ............ kernel=poly, C=50, degree=2, score=0.708661 -   0.2s
# [CV] kernel=rbf, C=50, degree=2 ......................................
# [CV] ............. kernel=rbf, C=50, degree=2, score=0.744526 -   0.0s
# [CV] kernel=rbf, C=50, degree=2 ......................................
# [CV] ............. kernel=rbf, C=50, degree=2, score=0.751773 -   0.0s
# [CV] kernel=rbf, C=50, degree=2 ......................................
# [CV] ............. kernel=rbf, C=50, degree=2, score=0.775194 -   0.0s
# [CV] kernel=sigmoid, C=50, degree=2 ..................................
# [CV] ......... kernel=sigmoid, C=50, degree=2, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=50, degree=2 ..................................
# [CV] ......... kernel=sigmoid, C=50, degree=2, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=50, degree=2 ..................................
# [CV] ......... kernel=sigmoid, C=50, degree=2, score=0.807229 -   0.0s
# [CV] kernel=linear, C=50, degree=3 ...................................
# [CV] .......... kernel=linear, C=50, degree=3, score=0.744526 -   2.7s
# [CV] kernel=linear, C=50, degree=3 ...................................
# [CV] .......... kernel=linear, C=50, degree=3, score=0.777778 -   5.2s
# [CV] kernel=linear, C=50, degree=3 ...................................
# [CV] .......... kernel=linear, C=50, degree=3, score=0.826087 -   5.4s
# [CV] kernel=poly, C=50, degree=3 .....................................
# [CV] ............ kernel=poly, C=50, degree=3, score=0.701493 -   0.0s
# [CV] kernel=poly, C=50, degree=3 .....................................
# [CV] ............ kernel=poly, C=50, degree=3, score=0.696296 -   0.0s
# [CV] kernel=poly, C=50, degree=3 .....................................
# [CV] ............ kernel=poly, C=50, degree=3, score=0.734375 -   0.0s
# [CV] kernel=rbf, C=50, degree=3 ......................................
# [CV] ............. kernel=rbf, C=50, degree=3, score=0.744526 -   0.0s
# [CV] kernel=rbf, C=50, degree=3 ......................................
# [CV] ............. kernel=rbf, C=50, degree=3, score=0.751773 -   0.0s
# [CV] kernel=rbf, C=50, degree=3 ......................................
# [CV] ............. kernel=rbf, C=50, degree=3, score=0.775194 -   0.0s
# [CV] kernel=sigmoid, C=50, degree=3 ..................................
# [CV] ......... kernel=sigmoid, C=50, degree=3, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=50, degree=3 ..................................
# [CV] ......... kernel=sigmoid, C=50, degree=3, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=50, degree=3 ..................................
# [CV] ......... kernel=sigmoid, C=50, degree=3, score=0.807229 -   0.0s
# [CV] kernel=linear, C=50, degree=4 ...................................
# [CV] .......... kernel=linear, C=50, degree=4, score=0.744526 -   3.1s
# [CV] kernel=linear, C=50, degree=4 ...................................
# [CV] .......... kernel=linear, C=50, degree=4, score=0.777778 -   5.1s
# [CV] kernel=linear, C=50, degree=4 ...................................
# [CV] .......... kernel=linear, C=50, degree=4, score=0.826087 -   5.7s
# [CV] kernel=poly, C=50, degree=4 .....................................
# [CV] ............ kernel=poly, C=50, degree=4, score=0.715328 -   0.0s
# [CV] kernel=poly, C=50, degree=4 .....................................
# [CV] ............ kernel=poly, C=50, degree=4, score=0.692308 -   0.0s
# [CV] kernel=poly, C=50, degree=4 .....................................
# [CV] ............ kernel=poly, C=50, degree=4, score=0.688525 -   0.1s
# [CV] kernel=rbf, C=50, degree=4 ......................................
# [CV] ............. kernel=rbf, C=50, degree=4, score=0.744526 -   0.0s
# [CV] kernel=rbf, C=50, degree=4 ......................................
# [CV] ............. kernel=rbf, C=50, degree=4, score=0.751773 -   0.0s
# [CV] kernel=rbf, C=50, degree=4 ......................................
# [CV] ............. kernel=rbf, C=50, degree=4, score=0.775194 -   0.0s
# [CV] kernel=sigmoid, C=50, degree=4 ..................................
# [CV] ......... kernel=sigmoid, C=50, degree=4, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=50, degree=4 ..................................
# [CV] ......... kernel=sigmoid, C=50, degree=4, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=50, degree=4 ..................................
# [CV] ......... kernel=sigmoid, C=50, degree=4, score=0.807229 -   0.0s
# [CV] kernel=linear, C=100, degree=1 ..................................
# [CV] ......... kernel=linear, C=100, degree=1, score=0.744526 -   5.8s
# [CV] kernel=linear, C=100, degree=1 ..................................
# [CV] ......... kernel=linear, C=100, degree=1, score=0.777778 -   7.0s
# [CV] kernel=linear, C=100, degree=1 ..................................
# [CV] ......... kernel=linear, C=100, degree=1, score=0.826087 -  10.6s
# [CV] kernel=poly, C=100, degree=1 ....................................
# [CV] ........... kernel=poly, C=100, degree=1, score=0.760563 -   0.1s
# [CV] kernel=poly, C=100, degree=1 ....................................
# [CV] ........... kernel=poly, C=100, degree=1, score=0.765957 -   0.1s
# [CV] kernel=poly, C=100, degree=1 ....................................
# [CV] ........... kernel=poly, C=100, degree=1, score=0.834532 -   0.6s
# [CV] kernel=rbf, C=100, degree=1 .....................................
# [CV] ............ kernel=rbf, C=100, degree=1, score=0.744526 -   0.0s
# [CV] kernel=rbf, C=100, degree=1 .....................................
# [CV] ............ kernel=rbf, C=100, degree=1, score=0.751773 -   0.0s
# [CV] kernel=rbf, C=100, degree=1 .....................................
# [CV] ............ kernel=rbf, C=100, degree=1, score=0.775194 -   0.0s
# [CV] kernel=sigmoid, C=100, degree=1 .................................
# [CV] ........ kernel=sigmoid, C=100, degree=1, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=100, degree=1 .................................
# [CV] ........ kernel=sigmoid, C=100, degree=1, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=100, degree=1 .................................
# [CV] ........ kernel=sigmoid, C=100, degree=1, score=0.807229 -   0.0s
# [CV] kernel=linear, C=100, degree=2 ..................................
# [CV] ......... kernel=linear, C=100, degree=2, score=0.744526 -   5.9s
# [CV] kernel=linear, C=100, degree=2 ..................................
# [CV] ......... kernel=linear, C=100, degree=2, score=0.777778 -   8.2s
# [CV] kernel=linear, C=100, degree=2 ..................................
# [CV] ......... kernel=linear, C=100, degree=2, score=0.826087 -   9.8s
# [CV] kernel=poly, C=100, degree=2 ....................................
# [CV] ........... kernel=poly, C=100, degree=2, score=0.681818 -   0.1s
# [CV] kernel=poly, C=100, degree=2 ....................................
# [CV] ........... kernel=poly, C=100, degree=2, score=0.681818 -   0.3s
# [CV] kernel=poly, C=100, degree=2 ....................................
# [CV] ........... kernel=poly, C=100, degree=2, score=0.734375 -   0.3s
# [CV] kernel=rbf, C=100, degree=2 .....................................
# [CV] ............ kernel=rbf, C=100, degree=2, score=0.744526 -   0.0s
# [CV] kernel=rbf, C=100, degree=2 .....................................
# [CV] ............ kernel=rbf, C=100, degree=2, score=0.751773 -   0.0s
# [CV] kernel=rbf, C=100, degree=2 .....................................
# [CV] ............ kernel=rbf, C=100, degree=2, score=0.775194 -   0.0s
# [CV] kernel=sigmoid, C=100, degree=2 .................................
# [CV] ........ kernel=sigmoid, C=100, degree=2, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=100, degree=2 .................................
# [CV] ........ kernel=sigmoid, C=100, degree=2, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=100, degree=2 .................................
# [CV] ........ kernel=sigmoid, C=100, degree=2, score=0.807229 -   0.0s
# [CV] kernel=linear, C=100, degree=3 ..................................
# [CV] ......... kernel=linear, C=100, degree=3, score=0.744526 -   5.4s
# [CV] kernel=linear, C=100, degree=3 ..................................
# [CV] ......... kernel=linear, C=100, degree=3, score=0.777778 -   8.5s
# [CV] kernel=linear, C=100, degree=3 ..................................
# [CV] ......... kernel=linear, C=100, degree=3, score=0.826087 -  10.0s
# [CV] kernel=poly, C=100, degree=3 ....................................
# [CV] ........... kernel=poly, C=100, degree=3, score=0.701493 -   0.0s
# [CV] kernel=poly, C=100, degree=3 ....................................
# [CV] ........... kernel=poly, C=100, degree=3, score=0.696296 -   0.0s
# [CV] kernel=poly, C=100, degree=3 ....................................
# [CV] ........... kernel=poly, C=100, degree=3, score=0.734375 -   0.1s
# [CV] kernel=rbf, C=100, degree=3 .....................................
# [CV] ............ kernel=rbf, C=100, degree=3, score=0.744526 -   0.0s
# [CV] kernel=rbf, C=100, degree=3 .....................................
# [CV] ............ kernel=rbf, C=100, degree=3, score=0.751773 -   0.0s
# [CV] kernel=rbf, C=100, degree=3 .....................................
# [CV] ............ kernel=rbf, C=100, degree=3, score=0.775194 -   0.0s
# [CV] kernel=sigmoid, C=100, degree=3 .................................
# [CV] ........ kernel=sigmoid, C=100, degree=3, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=100, degree=3 .................................
# [CV] ........ kernel=sigmoid, C=100, degree=3, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=100, degree=3 .................................
# [CV] ........ kernel=sigmoid, C=100, degree=3, score=0.807229 -   0.0s
# [CV] kernel=linear, C=100, degree=4 ..................................
# [CV] ......... kernel=linear, C=100, degree=4, score=0.744526 -   5.6s
# [CV] kernel=linear, C=100, degree=4 ..................................
# [CV] ......... kernel=linear, C=100, degree=4, score=0.777778 -   8.4s
# [CV] kernel=linear, C=100, degree=4 ..................................
# [CV] ......... kernel=linear, C=100, degree=4, score=0.826087 -   9.9s
# [CV] kernel=poly, C=100, degree=4 ....................................
# [CV] ........... kernel=poly, C=100, degree=4, score=0.715328 -   0.0s
# [CV] kernel=poly, C=100, degree=4 ....................................
# [CV] ........... kernel=poly, C=100, degree=4, score=0.692308 -   0.0s
# [CV] kernel=poly, C=100, degree=4 ....................................
# [CV] ........... kernel=poly, C=100, degree=4, score=0.688525 -   0.0s
# [CV] kernel=rbf, C=100, degree=4 .....................................
# [CV] ............ kernel=rbf, C=100, degree=4, score=0.744526 -   0.0s
# [CV] kernel=rbf, C=100, degree=4 .....................................
# [CV] ............ kernel=rbf, C=100, degree=4, score=0.751773 -   0.0s
# [CV] kernel=rbf, C=100, degree=4 .....................................
# [CV] ............ kernel=rbf, C=100, degree=4, score=0.775194 -   0.0s
# [CV] kernel=sigmoid, C=100, degree=4 .................................
# [CV] ........ kernel=sigmoid, C=100, degree=4, score=0.804734 -   0.0s
# [CV] kernel=sigmoid, C=100, degree=4 .................................
# [CV] ........ kernel=sigmoid, C=100, degree=4, score=0.802395 -   0.0s
# [CV] kernel=sigmoid, C=100, degree=4 .................................
# [CV] ........ kernel=sigmoid, C=100, degree=4, score=0.807229 -   0.0s
# Made predictions in 0.0110 seconds.
# Tuned model has a training F1 score of 0.8408.
# Made predictions in 0.0040 seconds.
# Tuned model has a testing F1 score of 0.8108.
# [Parallel(n_jobs=1)]: Done 288 out of 288 | elapsed:  2.8min finished

# %%
print("clf Best Params: {}".format(grid_obj.best_params_))
# Out:
# clf Best Params: {'kernel': 'poly', 'C': 2, 'degree': 1}

# %% [markdown]
# ### Question 5 - Final F<sub>1</sub> Score
# *What is the final model's F<sub>1</sub> score for training and testing? How does that score compare to the untuned model?*

# %% [markdown]
# **Answer: ** The final F1 score for the tuned model is:
# F1 Score - Training: 0.8408 (Tuned) VS 0.8577 (Non-Tuned)
# F1 Score - Testing:  0.8108 (Tuned) VS 0.8108 (Non-Tuned)
#
# I expected to have a better score after tuning but the result is very trange as I can see that the training score decreased on tuning and the testing score is the same after tuning

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to
# **File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
